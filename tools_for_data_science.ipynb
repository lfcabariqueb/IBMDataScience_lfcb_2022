# %% [markdown]
# # My Jupyter Notebook on Github

# %% [markdown]
# Name: **Luis F Cabarique B**
#
# Desired occupation: Data Scientist

# %% [markdown]
# *I am interested in Data Science because of the wide amount of fields in which it can be applied. I also find it very interesting to study data to draw insights and make predictions. I find it very valuable to be able to advise policy and decision makers with data based insights.*

# %% [markdown]
# ### Code in cell 5 prints a simple message

# %%
result = 3 * 2 + 4

print("Hello, the result is {}.".format(result))
# Out:
# Hello, the result is 10.

# %% [markdown]
# ## More markdown features
#
# ---
# ### Bullet list
#
# * Item
# * Another item
# * Yet another item
#
# ---
#
# ### Numbered list
#
# 1. Item
# 2. Another item
# 3. Yet another item
#
# ---
#
# ### Table
#
# Animal | Males | Females
# --- | --- | ---
# Tiger | 1 | 1
# Chimpanzee | 3 | 5
#
# ---
#
# ### Links
#
# [This link goes to google](https://www.google.com)
#
# [This link does not go to google](https://www.bing.com)
#
# ---
#
# ### Image
#
# ![alt text](https://2.bp.blogspot.com/-GIlJEJipaQ4/Utf4fwrNwEI/AAAAAAAACYQ/-qWfrQYSbZU/s1600/iceland-gull-nice.JPG "This is a gull")
#
# ---
#
# ### Code highlighting
#
# ```python
# name = "Pepe Barrios"
# apples = 5
# print("{person} has {apple_count} apples.".format(person=name, apple_count=apples))
# ```
#
# ---
#
# ### Blocked quotes
#
# > This sentence is a lie.
# > Is it?
#
# ---
#
# ### Strikethrough
#
# ~~This is a discarded idea~~
